# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import sympy as sp
from matplotlib.ticker import MultipleLocator 
import pandas as pd


import pandas as pd
import cmath
import math



pf_med = pd.read_csv('bodeFAAnozoom.csv', header=None)
freq = pf_med[0]
V2_module = pf_med[2]

# Create a list of complex numbers using V2_module and V2_phase

# Perform element-wise division of complex numbers by 189000


# Calculate Z_in as the reciprocal of I_in


# Calculate the absolute value of Z_in


# Calculate the phase of Z_in

ax_bode, ax_bode = plt.subplots(figsize=(10,4))

ax_bode.semilogx(freq,V2_module,'p-' , label='$ Z_in $', marker='o',markersize=0.3)

#Edición de presentación

ax_bode.set(xlabel='Frecuencia (Hz)', ylabel='Impedancia (KOhm)', title='Gráfica del modúlo de la impedancia de entrada$')
ax_bode.grid(True)

#Límites del gráfico

ax_bode.set_xlim(10e3,10e5)
#ax_bode.xaxis.set_major_locator(MultipleLocator(10000))
#ax_phase.set_xlim(1*10**1, 2*10**5)

ax_bode.grid(visible=True, which='both', axis='both',linewidth=0.3)
ax_bode.grid(visible=True, which='major', axis='both',linewidth=1)
ax_bode.legend()
ax_bode.minorticks_on()

plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# C:\Users\Santiago\AppData\Local\Temp\ipykernel_3452\2093440719.py:35: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "p-" (-> marker='p'). The keyword argument will take precedence.
#   ax_bode.semilogx(freq,V2_module,'p-' , label='$ Z_in $', marker='o',markersize=0.3)
