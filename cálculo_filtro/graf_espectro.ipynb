# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import sympy as sp
from matplotlib.ticker import MultipleLocator 
import pandas as pd


import pandas as pd
import cmath
import math



pf_med = pd.read_csv('FFTrampa2V.csv', header=None)
freq = pf_med[0]/1000
V2_module = pf_med[3]
V1_module = pf_med[1]

# Create a list of complex numbers using V2_module and V2_phase

# Perform element-wise division of complex numbers by 189000


# Calculate Z_in as the reciprocal of I_in


# Calculate the absolute value of Z_in


# Calculate the phase of Z_in

ax_bode, ax_bode = plt.subplots(figsize=(10,4))

ax_bode.plot(freq,V2_module,'p-' , label='$ out_FAA $', marker='o',markersize=0.1)
ax_bode.plot(freq+0.5,V1_module,'p-' , label='$ in_FAA $', marker='o',markersize=0.1)

#Edición de presentación

ax_bode.set(xlabel='Frecuencia (kHz)', ylabel='Ganancia (dBV)', title='Gráfica del espectro espectro a la entrada y salida del FAA$')
ax_bode.grid(True)

#Límites del gráfico

ax_bode.set_xlim(5,1.5e2)
ax_bode.set_ylim(-50,0)
ax_bode.xaxis.set_major_locator(MultipleLocator(7.20))
#ax_phase.set_xlim(1*10**1, 2*10**5)
leg = ax_bode.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))
for text in leg.get_texts():
    text.set_rotation('vertical')
ax_bode.grid(visible=True, which='both', axis='both',linewidth=0.3)
ax_bode.grid(visible=True, which='major', axis='both',linewidth=1)
ax_bode.legend()
ax_bode.minorticks_on()

plt.minorticks_on()

plt.show()
# Out:
# C:\Users\Santiago\AppData\Local\Temp\ipykernel_11444\600351969.py:36: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "p-" (-> marker='p'). The keyword argument will take precedence.
#   ax_bode.plot(freq,V2_module,'p-' , label='$ out_FAA $', marker='o',markersize=0.1)
# C:\Users\Santiago\AppData\Local\Temp\ipykernel_11444\600351969.py:37: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "p-" (-> marker='p'). The keyword argument will take precedence.
#   ax_bode.plot(freq+0.5,V1_module,'p-' , label='$ in_FAA $', marker='o',markersize=0.1)

# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import sympy as sp
from matplotlib.ticker import MultipleLocator 
import pandas as pd


import pandas as pd
import cmath
import math



pf_med = pd.read_csv('FFT_Rampa_Zoom_FR.csv', header=None)
freq = pf_med[0]/1000
V2_module = pf_med[3]
V1_module = pf_med[1]

# Create a list of complex numbers using V2_module and V2_phase

# Perform element-wise division of complex numbers by 189000


# Calculate Z_in as the reciprocal of I_in


# Calculate the absolute value of Z_in


# Calculate the phase of Z_in

ax_bode, ax_bode = plt.subplots(figsize=(10,4))

ax_bode.plot(freq,V2_module,'p-' , label='$ out_FR $', marker='o',markersize=0.1)
ax_bode.plot(freq+0.5,V1_module,'p-' , label='$ in_FR $', marker='o',markersize=0.1)

#Edición de presentación

ax_bode.set(xlabel='Frecuencia (kHz)', ylabel='Ganancia (dBV)', title='Gráfica del espectro espectro a la entrada y salida del FR$')
ax_bode.grid(True)

#Límites del gráfico

ax_bode.set_xlim(5,1.5e2)
ax_bode.set_ylim(-50,0)
ax_bode.xaxis.set_major_locator(MultipleLocator(7.20))
#ax_phase.set_xlim(1*10**1, 2*10**5)
leg = ax_bode.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))
for text in leg.get_texts():
    text.set_rotation('vertical')
ax_bode.grid(visible=True, which='both', axis='both',linewidth=0.3)
ax_bode.grid(visible=True, which='major', axis='both',linewidth=1)
ax_bode.legend()
ax_bode.minorticks_on()

plt.minorticks_on()

plt.show()
# Out:
# C:\Users\Santiago\AppData\Local\Temp\ipykernel_11444\677440674.py:36: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "p-" (-> marker='p'). The keyword argument will take precedence.
#   ax_bode.plot(freq,V2_module,'p-' , label='$ out_FR $', marker='o',markersize=0.1)
# C:\Users\Santiago\AppData\Local\Temp\ipykernel_11444\677440674.py:37: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "p-" (-> marker='p'). The keyword argument will take precedence.
#   ax_bode.plot(freq+0.5,V1_module,'p-' , label='$ in_FR $', marker='o',markersize=0.1)
